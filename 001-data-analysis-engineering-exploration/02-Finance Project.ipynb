# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# ** NOTE: This project is extremely challenging because it will introduce a lot of new concepts and have you looking things up on your own (we'll point you in the right direction) to try to solve the tasks issued. Feel free to just go through the solutions lecture notebook and video as a "walkthrough" project if you don't want to have to look things up yourself. You'll still learn a lot that way! **
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
# import pandas_datareader as pdr
import yfinance as yf
import datetime
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# ### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google" MAY NOT ALWAYS WORK.
# ------------
# ### We also provide pickle file in the article lecture right before the video lectures.

# %%
start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)

BAC = yf.download("BAC", start=start, end=end)

C = yf.download("C", start=start, end=end)

GS = yf.download("GS", start=start, end=end)

JPM = yf.download("JPM", start=start, end=end)

MS = yf.download("MS", start=start, end=end)

WFC = yf.download("WFC", start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
WFC.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  31.600000  31.975000  31.195000  31.900000  19.695122  11016400
# 2006-01-04  31.799999  31.820000  31.365000  31.530001  19.466679  10870000
# 2006-01-05  31.500000  31.555000  31.309999  31.495001  19.445070  10158000
# 2006-01-06  31.580000  31.775000  31.385000  31.680000  19.559284   8403800
# 2006-01-09  31.674999  31.825001  31.555000  31.674999  19.556200   5619600

# %%
for col in WFC.columns:
    print(col)
# Out:
# Open
# High
# Low
# Close
# Adj Close
# Volume

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], axis=1, keys=tickers)

bank_stocks.head()
# Out:
#                   BAC                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  32.956554  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  32.606556  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  32.648560  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  32.599556  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  32.620556  15619400
#
#                      C                                      ...         MS  \
#                   Open        High         Low       Close  ...        Low
# Date                                                        ...
# 2006-01-03  490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04  488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  32.956554  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  32.606556  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  32.648560  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  32.599556  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  32.620556  15619400
#
# Bank Ticker           C                                      ...         MS  \
# Stock Info         Open        High         Low       Close  ...        Low
# Date                                                         ...
# 2006-01-03   490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04   488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %%
# answer from original notebook
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker             ...        MS                                  WFC  \
# Stock Info    Volume    ...      Open   High    Low  Close   Volume   Open
# Date                    ...
# 2006-01-03   1537660    ...     57.17  58.49  56.74  58.31  5377000  31.60
# 2006-01-04   1871020    ...     58.70  59.28  58.35  58.35  7977800  31.80
# 2006-01-05   1143160    ...     58.55  58.59  58.02  58.51  5778000  31.50
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
max_close_prices = bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()

print(max_close_prices)
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
# answer from original notebook
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = bank_stocks.copy()
returns = returns.reindex(index=bank_stocks.index, columns=bank_stocks.columns)

print(returns.head())
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  32.956554  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  32.606556  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  32.648560  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  32.599556  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  32.620556  15619400
#
# Bank Ticker           C                                      ...         MS  \
# Stock Info         Open        High         Low       Close  ...        Low
# Date                                                         ...
# 2006-01-03   490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04   488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
returns = bank_stocks.copy()

for ticker in tickers:
    returns[ticker, 'Return'] = bank_stocks[ticker]['Close'].pct_change()

returns = returns.xs(key='Return', axis=1, level=1)

returns = returns.add_suffix(' Return')

print(returns.head())
# Out:
# Bank Ticker  BAC Return  C Return  GS Return  JPM Return  MS Return  \
# Date
# 2006-01-03          NaN       NaN        NaN         NaN        NaN
# 2006-01-04    -0.010620 -0.018462  -0.013812   -0.014183   0.000686
# 2006-01-05     0.001288  0.004961  -0.000393    0.003029   0.002742
# 2006-01-06    -0.001501  0.000000   0.014169    0.007046   0.001025
# 2006-01-09     0.000644 -0.004731   0.012030    0.016242   0.010586
#
# Bank Ticker  WFC Return
# Date
# 2006-01-03          NaN
# 2006-01-04    -0.011599
# 2006-01-05    -0.001110
# 2006-01-06     0.005874
# 2006-01-09    -0.000158

# %%
# answer from original notebook
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
sns.pairplot(data=returns)

# %%
# answer from original notebook

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
best_returns = returns.idxmax()
worst_returns = returns.idxmin()

print('Best single day returns:')
print(best_returns)
print('\nWorst single day returns:')
print(worst_returns)
# Out:
# Best single day returns:
# Bank Ticker
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]
#
# Worst single day returns:
# Bank Ticker
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
# answer from original notebook
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %%
# answer from original notebook
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
std_returns = returns.std()

print('Standard deviations of returns:')
print(std_returns)
# Out:
# Standard deviations of returns:
# Bank Ticker
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
# answer from original notebook
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
returns_2015 = returns.loc['2015-01-01':'2015-12-31']

std_returns_2015 = returns_2015.std()

print('\nStandard deviations of returns in 2015:')
print(std_returns_2015)
# Out:
# Standard deviations of returns in 2015:
# Bank Ticker
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
# answer from original notebook
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# ** Create a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
ms_returns_2015 = returns_2015['MS Return']

sns.displot(ms_returns_2015, bins=100, kde=True)

plt.title('Distribution of 2015 Returns for Morgan Stanley')
plt.xlabel('Returns')
plt.ylabel('Frequency')
# Out:
# Text(13.819444444444445, 0.5, 'Frequency')

# %%
# answer from original notebook
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
c_returns_2008 = returns.loc['2008-01-01':'2008-12-31']['C Return']

sns.displot(c_returns_2008, bins=100, kde=True)

plt.title('Distribution of 2008 Returns for CitiGroup')
plt.xlabel('Returns')
plt.ylabel('Frequency')
# Out:
# Text(0.6944444444444446, 0.5, 'Frequency')

# %%
# answer from original notebook
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
plt.figure(figsize=(12,6))

for ticker in tickers:
    bank_stocks[ticker]['Close'].plot(label=ticker)

plt.title('Closing Stock Prices for Banks')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()

# %%
# answer from original notebook

# %%
plt.figure(figsize=(12,6))

close_df = pd.DataFrame()
for ticker in tickers:
    close_df[ticker] = bank_stocks[ticker]['Close']

sns.lineplot(data=close_df)

plt.title('Closing Stock Prices for Banks')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(tickers)

# %%
# answer from original notebook

# %%
import plotly.graph_objs as go

traces = []
for ticker in tickers:
    trace = go.Scatter(x=bank_stocks[ticker].index, y=bank_stocks[ticker]['Close'], name=ticker)
    traces.append(trace)

layout = go.Layout(title='Closing Stock Prices for Banks', xaxis=dict(title='Date'), yaxis=dict(title='Closing Price'))

fig = go.Figure(data=traces, layout=layout)

fig.show()
# Out:
# <div>                            <div id="07f213a8-1e5f-46f8-aef2-26ae8ae51d60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07f213a8-1e5f-46f8-aef2-26ae8ae51d60")) {                    Plotly.newPlot(                        "07f213a8-1e5f-46f8-aef2-26ae8ae51d60",                        [{"name":"BAC","x":["2006-01-03T00:00:00","2006-01-04T00:00:00","2006-01-05T00:00:00","2006-01-06T00:00:00","2006-01-09T00:00:00","2006-01-10T00:00:00","2006-01-11T00:00:00","2006-01-12T00:00:00","2006-01-13T00:00:00","2006-01-17T00:00:00","2006-01-18T00:00:00","2006-01-19T00:00:00","2006-01-20T00:00:00","2006-01-23T00:00:00","2006-01-24T00:00:00","2006-01-25T00:00:00","2006-01-26T00:00:00","2006-01-27T00:00:00","2006-01-30T00:00:00","2006-01-31T00:00:00","2006-02
# ...

# %%
# answer from original notebook
# Out:
# <div id="16023fe4-0ed5-4915-a2b7-5e2290f9cf2e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("16023fe4-0ed5-4915-a2b7-5e2290f9cf2e", [{"type": "scatter", "x": ["2006-01-03", "2006-01-04", "2006-01-05", "2006-01-06", "2006-01-09", "2006-01-10", "2006-01-11", "2006-01-12", "2006-01-13", "2006-01-17", "2006-01-18", "2006-01-19", "2006-01-20", "2006-01-23", "2006-01-24", "2006-01-25", "2006-01-26", "2006-01-27", "2006-01-30", "2006-01-31", "2006-02-01", "2006-02-02", "2006-02-03", "2006-02-06", "2006-02-07", "2006-02-08", "2006-02-09", "2006-02-10", "2006-02-13", "2006-02-14", "2006-02-15", "2006-02-16", "2006-02-17", "2006-02-21", "2006-02-22", "2006-02-23", "2006-02-24", "2006-02-27", "2006-02-28", "2006-03-01", "2006-03-02", "2006-03-03", "2006-03-06", "2006-03-07", "2006-03-08", "2006-03-09", "200
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize=(12,6))

bac_2008 = bank_stocks['BAC'].loc['2008']

bac_rolling_30 = bac_2008['Close'].rolling(window=30).mean()

sns.set_style('whitegrid')
sns.lineplot(x=bac_2008.index, y=bac_2008['Close'], label='Close')
sns.lineplot(x=bac_rolling_30.index, y=bac_rolling_30, label='Rolling 30-Day Average')

plt.title('Bank of America Stock Price in 2008')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
# answer from original notebook

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
corr = bank_stocks.xs('Close', axis=1, level='Stock Info').corr()

sns.set_style('whitegrid')
sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.title('Correlation Between Stocks\' Close Price')
# Out:
# Text(0.5, 1.0, "Correlation Between Stocks' Close Price")

# %%
# answer from original notebook

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
corr = bank_stocks.xs('Close', axis=1, level='Stock Info').corr()

sns.clustermap(corr, annot=True, cmap='coolwarm')

plt.title('Clustermap of Correlation Between Stocks\' Close Price')
# Out:
# Text(0.5, 1.0, "Clustermap of Correlation Between Stocks' Close Price")

# %%
# answer from original notebook

# %%
import plotly.express as px
import plotly.figure_factory as ff

corr = bank_stocks.xs('Close', axis=1, level='Stock Info').corr()

fig = ff.create_annotated_heatmap(
    z=corr.values,
    x=list(corr.columns),
    y=list(corr.index),
    colorscale='RdBu',
    annotation_text=corr.round(2).values,
    showscale=True,
)

fig.update_layout(
    title='Clustermap of Correlation Between Stocks\' Close Price',
    xaxis=dict(title='Stocks'),
    yaxis=dict(title='Stocks'),
    height=700,
)

fig.show()
# Out:
# <div>                            <div id="5ff70b2e-17ae-423f-a74a-5d449020b926" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ff70b2e-17ae-423f-a74a-5d449020b926")) {                    Plotly.newPlot(                        "5ff70b2e-17ae-423f-a74a-5d449020b926",                        [{"colorscale":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"reversescale":false,"showscale":true,"x":["BAC","C","GS","JPM","MS","WFC"],"y":["BAC","C","GS","JPM","MS","WFC"],"z":[[1.0,0.9715160166987212,0.5508978624006278,0.10387407233619565,0.94421
# ...

# %%
# answer from original notebook
# Out:
# <div id="cfe3f8e3-825e-438f-9ede-9f7bd2e2ad65" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cfe3f8e3-825e-438f-9ede-9f7bd2e2ad65", [{"type": "heatmap", "x": ["BAC", "C", "GS", "JPM", "MS", "WFC"], "y": ["BAC", "C", "GS", "JPM", "MS", "WFC"], "colorscale": [[0.0, "rgb(165,0,38)"], [0.1, "rgb(215,48,39)"], [0.2, "rgb(244,109,67)"], [0.3, "rgb(253,174,97)"], [0.4, "rgb(254,224,144)"], [0.5, "rgb(255,255,191)"], [0.6, "rgb(224,243,248)"], [0.7, "rgb(171,217,233)"], [0.8, "rgb(116,173,209)"], [0.9, "rgb(69,117,180)"], [1.0, "rgb(49,54,149)"]], "z": [[1.0, 0.9715137697087325, 0.5509501372549771, 0.10389606365085878, 0.9442192943385206, 0.008566851425732356], [0.9715137697087325, 1.0, 0.4341706182992412, 0.003539648273630715, 0.9336049414173658, -0.06844121334375318], [0.5509501372549771, 0.43417061829
# ...

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)

bac = bank_stocks['BAC'].loc['2015-01-01':'2016-01-01']

trace = go.Candlestick(x=bac.index,
                       open=bac['Open'],
                       high=bac['High'],
                       low=bac['Low'],
                       close=bac['Close'])

layout = go.Layout(title='Candlestick Chart for Bank of America Stock (2015)',
                   xaxis={'title': 'Date'},
                   yaxis={'title': 'Price'})

fig = go.Figure(data=[trace], layout=layout)
iplot(fig, show_link=False)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
# answer from original notebook
# Out:
# <div id="071ad9fe-8200-4720-8c8f-bc34d62e3243" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("071ad9fe-8200-4720-8c8f-bc34d62e3243", [{"type": "box", "x": ["2015-01-08", "2015-01-08", "2015-01-08", "2015-01-08", "2015-01-08", "2015-01-08", "2015-01-14", "2015-01-14", "2015-01-14", "2015-01-14", "2015-01-14", "2015-01-14", "2015-01-16", "2015-01-16", "2015-01-16", "2015-01-16", "2015-01-16", "2015-01-16", "2015-01-21", "2015-01-21", "2015-01-21", "2015-01-21", "2015-01-21", "2015-01-21", "2015-01-22", "2015-01-22", "2015-01-22", "2015-01-22", "2015-01-22", "2015-01-22", "2015-01-26", "2015-01-26", "2015-01-26", "2015-01-26", "2015-01-26", "2015-01-26", "2015-01-27", "2015-01-27", "2015-01-27", "2015-01-27", "2015-01-27", "2015-01-27", "2015-01-29", "2015-01-29", "2015-01-29", "2015-01-29", "2015-01
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
ms_2015 = bank_stocks.loc['2015', ('MS', slice(None))]

ms_2015['SMA'] = ms_2015[('MS', 'Adj Close')].rolling(window=50).mean()

plt.figure(figsize=(12, 6))
plt.plot(ms_2015.index, ms_2015[('MS', 'Adj Close')], label='Adjusted Close')
plt.plot(ms_2015.index, ms_2015['SMA'], label='Simple Moving Average', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Morgan Stanley Adjusted Close Price and Simple Moving Average (2015)')
plt.legend()

# %%
cf.go_offline()

ms_2015 = bank_stocks.loc['2015', ('MS', slice(None))]

ms_2015[('MS', 'SMA_13')] = ms_2015[('MS', 'Adj Close')].rolling(window=13).mean()
ms_2015[('MS', 'SMA_21')] = ms_2015[('MS', 'Adj Close')].rolling(window=21).mean()
ms_2015[('MS', 'SMA_55')] = ms_2015[('MS', 'Adj Close')].rolling(window=55).mean()

ms_2015_sma = ms_2015[[('MS', 'Adj Close'), ('MS', 'SMA_13'), ('MS', 'SMA_21'), ('MS', 'SMA_55')]]
ms_2015_sma.columns = pd.MultiIndex.from_tuples([('MS', 'Adj Close'), ('MS', 'SMA_13'), ('MS', 'SMA_21'), ('MS', 'SMA_55')])

ms_2015_sma.columns = ms_2015_sma.columns.droplevel(0)

ms_2015_sma.iplot(title='Morgan Stanley Adjusted Close Price and Simple Moving Averages (2015)',
                  xTitle='Date', yTitle='Price')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="bbc3a6cf-36bd-4c45-9b36-c557cfc03697" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# answer from original notebook
# Out:
# <div id="a9f847d1-e9ad-48ea-8bfe-890e01f77235" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a9f847d1-e9ad-48ea-8bfe-890e01f77235", [{"type": "scatter", "x": ["2015-01-02", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-09", "2015-03-10", "201
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
bac_2015 = bank_stocks.loc['2015', ('BAC', slice(None))]

bac_2015[('BAC', 'SMA_20')] = bac_2015[('BAC', 'Adj Close')].rolling(window=20).mean()
bac_2015[('BAC', 'STD_20')] = bac_2015[('BAC', 'Adj Close')].rolling(window=20).std()
bac_2015[('BAC', 'Upper Band')] = bac_2015[('BAC', 'SMA_20')] + (bac_2015[('BAC', 'STD_20')] * 2)
bac_2015[('BAC', 'Lower Band')] = bac_2015[('BAC', 'SMA_20')] - (bac_2015[('BAC', 'STD_20')] * 2)

fig = go.Figure()

fig.add_trace(go.Scatter(x=bac_2015.index, y=bac_2015[('BAC', 'Adj Close')], mode='lines', name='Adjusted Close'))
fig.add_trace(go.Scatter(x=bac_2015.index, y=bac_2015[('BAC', 'SMA_20')], mode='lines', name='20-day SMA'))
fig.add_trace(go.Scatter(x=bac_2015.index, y=bac_2015[('BAC', 'Upper Band')], mode='lines', name='Upper Band'))
fig.add_trace(go.Scatter(x=bac_2015.index, y=bac_2015[('BAC', 'Lower Band')], mode='lines', name='Lower Band'))

fig.update_layout(title='Bank of America Bollinger Bands (2015)',
                  xaxis_title='Date', yaxis_title='Price')

fig.show()
# Out:
# <div>                            <div id="349e3832-699c-43be-bfab-e635871ae7c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("349e3832-699c-43be-bfab-e635871ae7c3")) {                    Plotly.newPlot(                        "349e3832-699c-43be-bfab-e635871ae7c3",                        [{"mode":"lines","name":"Adjusted Close","x":["2015-01-02T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","201
# ...

# %%
# answer from original notebook
# Out:
# <div id="19636ba2-6dc1-427c-9d79-7e8870cac1c9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("19636ba2-6dc1-427c-9d79-7e8870cac1c9", [{"type": "scatter", "x": ["2015-01-02", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-09", "2015-03-10", "201
# ...

# %% [markdown]
# # Great Job!
#
# Definitely a lot of more specific finance topics here, so don't worry if you didn't understand them all! The only thing you should be concerned with understanding are the basic pandas and visualization oeprations.
